# %%
1+1
# Out:
# 2

# %% [markdown]
# This is a bunch of markdown text

# %%
using Pkg
Pkg.activate(".")
using Plots
plot(rand(10))
# Out:
#   Activating project at `C:\Users\tim\Documents\2023examples\02-03`
